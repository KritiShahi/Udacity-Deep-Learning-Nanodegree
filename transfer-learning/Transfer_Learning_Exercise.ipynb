# %% [markdown]
# <a href="https://colab.research.google.com/github/KritiShahi/Udacity-Deep-Learning-Nanodegree/blob/master/transfer-learning/Transfer_Learning_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Transfer Learning
#
# Most of the time you won't want to train a whole convolutional network yourself. Modern ConvNets training on huge datasets like ImageNet take weeks on multiple GPUs.
# > Instead, most people use a pretrained network either as a fixed feature extractor, or as an initial network to fine tune.
#
# In this notebook, you'll be using [VGGNet](https://arxiv.org/pdf/1409.1556.pdf) trained on the [ImageNet dataset](http://www.image-net.org/) as a feature extractor. Below is a diagram of the VGGNet architecture, with a series of convolutional and maxpooling layers, then three fully-connected layers at the end that classify the 1000 classes found in the ImageNet database.
#
# <img src="https://github.com/KritiShahi/deep-learning-v2-pytorch/blob/master/transfer-learning/notebook_ims/vgg_16_architecture.png?raw=1" width=700px>
#
# VGGNet is great because it's simple and has great performance, coming in second in the ImageNet competition. The idea here is that we keep all the convolutional layers, but **replace the final fully-connected layer** with our own classifier. This way we can use VGGNet as a _fixed feature extractor_ for our images then easily train a simple classifier on top of that.
# * Use all but the last fully-connected layer as a fixed feature extractor.
# * Define a new, final classification layer and apply it to a task of our choice!
#
# You can read more about transfer learning from [the CS231n Stanford course notes](http://cs231n.github.io/transfer-learning/).
#
# ---

# %% [markdown]
# ## Flower power
#
# Here we'll be using VGGNet to classify images of flowers. We'll start, as usual, by importing our usual resources. And checking if we can train our model on GPU.
#
# ### Download Data
#
# Download the flower data from [this link](https://s3.amazonaws.com/video.udacity-data.com/topher/2018/September/5baa60a0_flower-photos/flower-photos.zip), save it in the home directory of this notebook and extract the zip file to get the directory `flower_photos/`. **Make sure the directory has this exact name for accessing data: flower_photos**.

# %%
import os
import numpy as np
import torch

import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# check if CUDA is available
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('CUDA is not available.  Training on CPU ...')
else:
    print('CUDA is available!  Training on GPU ...')
# Out:
# CUDA is available!  Training on GPU ...

# %% [markdown]
# ## Load and Transform our Data
#
# We'll be using PyTorch's [ImageFolder](https://pytorch.org/docs/stable/torchvision/datasets.html#imagefolder) class which makes it very easy to load data from a directory. For example, the training images are all stored in a directory path that looks like this:
# ```
# root/class_1/xxx.png
# root/class_1/xxy.png
# root/class_1/xxz.png
#
# root/class_2/123.png
# root/class_2/nsdf3.png
# root/class_2/asd932_.png
# ```
#
# Where, in this case, the root folder for training is `flower_photos/train/` and the classes are the names of flower types.

# %%
# Downloading the flower_photos folder
# !wget - c https://s3.amazonaws.com/video.udacity-data.com/topher/2018/September/5baa60a0_flower-photos/flower-photos.zip
# !unzip flower-photos.zip

# define training and test data directories
data_dir = 'flower_photos/'
train_dir = os.path.join(data_dir, 'train/')
test_dir = os.path.join(data_dir, 'test/')

# classes are folders in each directory with these names
classes = ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']
# Out:
# --2020-07-07 08:48:48--  http://-/
# Resolving - (-)... failed: Name or service not known.
# wget: unable to resolve host address ‘-’
# --2020-07-07 08:48:48--  http://c/
# Resolving c (c)... failed: Name or service not known.
# wget: unable to resolve host address ‘c’
# --2020-07-07 08:48:48--  https://s3.amazonaws.com/video.udacity-data.com/topher/2018/September/5baa60a0_flower-photos/flower-photos.zip
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.144.237
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.144.237|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 229734282 (219M) [application/zip]
# Saving to: ‘flower-photos.zip.3’
#
# flower-photos.zip.3 100%[===================>] 219.09M  16.3MB/s    in 15s
#
# 2020-07-07 08:49:04 (14.4 MB/s) - ‘flower-photos.zip.3’ saved [229734282/229734282]
#
# FINISHED --2020-07-07 08:49:04--
# Total wall clock time: 16s
# Downloaded: 1 files, 219M in 15s (14.4 MB/s)
# Archive:  flower-photos.zip
# replace flower_photos/.DS_Store? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: flower_photos/.DS_Store
#   inflating: __MACOSX/flower_photos/._.DS_Store
#   inflating: flower_photos/LICENSE.txt
#   inflating: flower_photos/test/.DS_Store
#   inflating: __MACOSX/flower_photos/test/._.DS_Store
#   inflating: flower_photos/test/daisy/14332947164_9b13513c71_m.jpg
#   inflating: flower_photos/test/daisy/14333681205_a07c9f1752_m.jpg
#   inflating: flower_photos/test/daisy/14350958832_29bdd3a254.jpg
#   inflating: flower_photos/test/daisy/14354051035_1037b30421_n.jpg
#   inflating: flower_photos/test/daisy/14372713423_61e2daae88.jpg
#   inflating: flower_photos/test/daisy/14399435971_ea5868c792.jpg
#   inflating: flower_photos/test/daisy/14402451388_56545a374a_n.jpg
#   inflating: flower_photos/test/daisy/14421389519_d5fd353eb4.jpg
#   inflating: flower_photos/test/daisy/14471433500_cdaa22e3ea_m.jpg
#   inflating: flower_photos/test/daisy/14485782498_fb342ec301.jpg
#   inflating: flower_photos/test/daisy/14507818175_05219b051c_m.jpg
#   inflating: flower_photos/test/daisy/14523675369_97c31d0b5b.jpg
#   inflating: flower_photos/test/daisy/14551098743_2842e7a004_n.jpg
#   inflating: flower_photos/test/daisy/14554906452_35f066ffe9_n.jpg
#   inflating: flower_photos/test/daisy/14564545365_1f1d267bf1_n.jpg
#   inflating: flower_photos/test/daisy/14569895116_32f0dcb0f9.jpg
#   inflating: flower_photos/test/daisy/14591326135_930703dbed_m.jpg
#   inflating: flower_photos/test/daisy/14600779226_7bbc288d40_m.jpg
#   inflating: flower_photos/test/daisy/14613443462_d4ed356201.jpg
#   inflating: flower_photos/test/daisy/14621687774_ec52811acd_n.jpg
#   inflating: flower_photos/test/daisy/14674743211_f68b13f6d9.jpg
#   inflating: flower_photos/test/daisy/14698531521_0c2f0c6539.jpg
#   inflating: flower_photos/test/daisy/14707111433_cce08ee007.jpg
#   inflating: flower_photos/test/daisy/14716799982_ed6d626a66.jpg
#   inflating: flower_photos/test/daisy/14816364517_2423021484_m.jpg
#   inflating: flower_photos/test/daisy/14866200659_6462c723cb_m.jpg
#   inflating: flower_photos/test/daisy/14907815010_bff495449f.jpg
#   inflating: flower_photos/test/daisy/14921511479_7b0a647795.jpg
#   inflating: flower_photos/test/daisy/15029936576_8d6f96c72c_n.jpg
#   inflating: flower_photos/test/daisy/15306268004_4680ba95e1.jpg
#   inflating: flower_photos/test/daisy/15327813273_06cdf42210.jpg
#   inflating: flower_photos/test/daisy/15760153042_a2a90e9da5_m.jpg
#   inflating: flower_photos/test/daisy/15760811380_4d686c892b_n.jpg
#   inflating: flower_photos/test/daisy/15784493690_b1858cdb2b_n.jpg
#   inflating: flower_photos/test/daisy/15813862117_dedcd1c56f_m.jpg
#   inflating: flower_photos/test/daisy/15853110333_229c439e7f.jpg
#   inflating: flower_photos/test/daisy/16020253176_60f2a6a5ca_n.jpg
#   inflating: flower_photos/test/daisy/16025261368_911703a536_n.jpg
#   inflating: flower_photos/test/daisy/16121105382_b96251e506_m.jpg
#   inflating: flower_photos/test/daisy/16161045294_70c76ce846_n.jpg
#   inflating: flower_photos/test/daisy/16291797949_a1b1b7c2bd_n.jpg
#   inflating: flower_photos/test/daisy/16360180712_b72695928c_n.jpg
#   inflating: flower_photos/test/daisy/16401288243_36112bd52f_m.jpg
#   inflating: flower_photos/test/daisy/16482676953_5296227d40_n.jpg
#   inflating: flower_photos/test/daisy/16492248512_61a57dfec1_m.jpg
#   inflating: flower_photos/test/daisy/16527403771_2391f137c4_n.jpg
#   inflating: flower_photos/test/daisy/16737503507_431768a927.jpg
#   inflating: flower_photos/test/daisy/16819071290_471d99e166_m.jpg
#   inflating: flower_photos/test/daisy/16833748795_b681b2839f_n.jpg
#   inflating: flower_photos/test/daisy/17027891179_3edc08f4f6.jpg
#   inflating: flower_photos/test/daisy/17101762155_2577a28395.jpg
#   inflating: flower_photos/test/daisy/17249393016_093e915012_n.jpg
#   inflating: flower_photos/test/daisy/17357636476_1953c07aa4_n.jpg
#   inflating: flower_photos/test/daisy/18023717391_e2c9089e10.jpg
#   inflating: flower_photos/test/daisy/18195689904_46619b7e16_n.jpg
#   inflating: flower_photos/test/daisy/18203367608_07a04e98a4_n.jpg
#   inflating: flower_photos/test/daisy/18354545086_693ea7bc2a.jpg
#   inflating: flower_photos/test/daisy/18400014056_2e4c601ed5.jpg
#   inflating: flower_photos/test/daisy/18442919723_d1251d3e14_n.jpg
#   inflating: flower_photos/test/daisy/18474740346_ffdaa18032.jpg
#   inflating: flower_photos/test/daisy/18582579815_4c6637e9ff_m.jpg
#   inflating: flower_photos/test/daisy/18622672908_eab6dc9140_n.jpg
#   inflating: flower_photos/test/daisy/18635898912_eb8e058ef0.jpg
#   inflating: flower_photos/test/daisy/18679421522_3be9879e32.jpg
#   inflating: flower_photos/test/daisy/18684594849_7dd3634f5e_n.jpg
#   inflating: flower_photos/test/daisy/18711159980_11d3bd5042.jpg
#   inflating: flower_photos/test/daisy/18901817451_43e2b45f6c.jpg
#   inflating: flower_photos/test/daisy/19019544592_b64469bf84_n.jpg
#   inflating: flower_photos/test/daisy/19177263840_6a316ea639.jpg
#   inflating: flower_photos/test/daisy/19178753159_a471bf4b6b.jpg
#   inflating: flower_photos/test/daisy/19280272025_57de24e940_m.jpg
#   inflating: flower_photos/test/daisy/19544831049_0d738d4872_m.jpg
#   inflating: flower_photos/test/daisy/19653086178_28156b7ce4_m.jpg
#   inflating: flower_photos/test/daisy/19813618946_93818db7aa_m.jpg
#   inflating: flower_photos/test/daisy/19834392829_7d697871f6.jpg
#   inflating: flower_photos/test/daisy/19865728236_a62f8f445b_n.jpg
#   inflating: flower_photos/test/daisy/19975899671_ebc42b7865_n.jpg
#   inflating: flower_photos/test/daisy/20182559506_40a112f762.jpg
#   inflating: flower_photos/test/daisy/20289938802_e16fa9f23d.jpg
#   inflating: flower_photos/test/daisy/20329326505_a777c71cc2.jpg
#   inflating: flower_photos/test/daisy/20580471306_ab5a011b15_n.jpg
#   inflating: flower_photos/test/daisy/20619292635_9857a12d54.jpg
#   inflating: flower_photos/test/daisy/20685027271_0e7306e7c1_n.jpg
#   inflating: flower_photos/test/daisy/20703737132_179560d0fb.jpg
#   inflating: flower_photos/test/daisy/20773528301_008fcbc5a1_n.jpg
#   inflating: flower_photos/test/daisy/20948886919_cac7844f34_n.jpg
#   inflating: flower_photos/test/daisy/21402054779_759366efb0_n.jpg
#   inflating: flower_photos/test/daisy/21626652132_97e1318bb8_m.jpg
#   inflating: flower_photos/test/daisy/21805938544_bf6bb0e4bc.jpg
#   inflating: flower_photos/test/daisy/22244161124_53e457bb66_n.jpg
#   inflating: flower_photos/test/daisy/22873310415_3a5674ec10_m.jpg
#   inflating: flower_photos/test/daisy/23095658544_7226386954_n.jpg
#   inflating: flower_photos/test/dandelion/16462263826_2555edeb74_n.jpg
#   inflating: flower_photos/test/dandelion/16495282564_d8c34d6a2e_m.jpg
#   inflating: flower_photos/test/dandelion/16510864164_3afa8ac37f.jpg
#   inflating: flower_photos/test/dandelion/16650892835_9228a3ef67_m.jpg
#   inflating: flower_photos/test/dandelion/16656127943_2f70926b6c.jpg
#   inflating: flower_photos/test/dandelion/16691236594_4287cea9d6_n.jpg
#   inflating: flower_photos/test/dandelion/16699732794_5bfd639cf8_n.jpg
#   inflating: flower_photos/test/dandelion/16713229021_bea2533981_n.jpg
#   inflating: flower_photos/test/dandelion/16716172029_2166d8717f_m.jpg
#   inflating: flower_photos/test/dandelion/16744522344_8d21b1530d_n.jpg
#   inflating: flower_photos/test/dandelion/16766166609_ccb8344c9f_m.jpg
#   inflating: flower_photos/test/dandelion/16817037661_2980d823e1_n.jpg
#   inflating: flower_photos/test/dandelion/16837594326_1056d875a4_m.jpg
#   inflating: flower_photos/test/dandelion/16863587471_cc3a6ffb29_m.jpg
#   inflating: flower_photos/test/dandelion/16949657389_ac0ee80fd1_m.jpg
#   inflating: flower_photos/test/dandelion/16953818045_fea21c8bf8.jpg
#   inflating: flower_photos/test/dandelion/16970837587_4a9d8500d7.jpg
#   inflating: flower_photos/test/dandelion/17020815734_81e8db8008_m.jpg
#   inflating: flower_photos/test/dandelion/17029965300_8e755c2214_n.jpg
#   inflating: flower_photos/test/dandelion/17047231499_bd66c23641.jpg
#   inflating: flower_photos/test/dandelion/17047385027_8fd510e164_n.jpg
#   inflating: flower_photos/test/dandelion/17075803866_aeeded2637.jpg
#   inflating: flower_photos/test/dandelion/17077940105_d2cd7b9ec4_n.jpg
#   inflating: flower_photos/test/dandelion/17080000869_a80e767f4a_m.jpg
#   inflating: flower_photos/test/dandelion/17122969189_0ec37cb6c9.jpg
#   inflating: flower_photos/test/dandelion/17135145776_4c2ec21b05_m.jpg
#   inflating: flower_photos/test/dandelion/17146644679_11aff3045c.jpg
#   inflating: flower_photos/test/dandelion/17147436650_c94ae24004_n.jpg
#   inflating: flower_photos/test/dandelion/17161833794_e1d92259d2_m.jpg
#   inflating: flower_photos/test/dandelion/17175932454_c052e205c1_n.jpg
#   inflating: flower_photos/test/dandelion/17189437699_a9171b6ae3.jpg
#   inflating: flower_photos/test/dandelion/17220096449_0e535989f0_n.jpg
#   inflating: flower_photos/test/dandelion/17243540220_65b98eb926_n.jpg
#   inflating: flower_photos/test/dandelion/17244252705_328e0bcda6.jpg
#   inflating: flower_photos/test/dandelion/17276354745_2e312a72b5_n.jpg
#   inflating: flower_photos/test/dandelion/17280886635_e384d91300_n.jpg
#   inflating: flower_photos/test/dandelion/17322195031_c2680809dc_m.jpg
#   inflating: flower_photos/test/dandelion/17344936845_fec4d626b7.jpg
#   inflating: flower_photos/test/dandelion/17346385582_7ba433dbbe.jpg
#   inflating: flower_photos/test/dandelion/17367866236_61abd4d243_n.jpg
#   inflating: flower_photos/test/dandelion/17388674711_6dca8a2e8b_n.jpg
#   inflating: flower_photos/test/dandelion/17388697431_0d84c427d1_n.jpg
#   inflating: flower_photos/test/dandelion/17420983523_2e32d70359.jpg
#   inflating: flower_photos/test/dandelion/17457028309_95514c8d02_n.jpg
#   inflating: flower_photos/test/dandelion/17466568484_9128287148.jpg
#   inflating: flower_photos/test/dandelion/17482158576_86c5ebc2f8.jpg
#   inflating: flower_photos/test/dandelion/17574213074_f5416afd84.jpg
#   inflating: flower_photos/test/dandelion/17619402434_15b2ec2d79.jpg
#   inflating: flower_photos/test/dandelion/17649230811_9bdbbacb8c.jpg
#   inflating: flower_photos/test/dandelion/17747738311_5014b1f77f.jpg
#   inflating: flower_photos/test/dandelion/17821459748_873101edd0_m.jpg
#   inflating: flower_photos/test/dandelion/17851831751_35b071f4b0.jpg
#   inflating: flower_photos/test/dandelion/17862580326_293070978d_m.jpg
#   inflating: flower_photos/test/dandelion/17903104293_9138439e76.jpg
#   inflating: flower_photos/test/dandelion/18001393975_2a6acaabd8.jpg
#   inflating: flower_photos/test/dandelion/18010259565_d6aae33ca7_n.jpg
#   inflating: flower_photos/test/dandelion/18089878729_907ed2c7cd_m.jpg
#   inflating: flower_photos/test/dandelion/18111636378_856027a7b8_n.jpg
#   inflating: flower_photos/test/dandelion/18183515403_13a9ca6d86_n.jpg
#   inflating: flower_photos/test/dandelion/18204150090_fb418bbddb.jpg
#   inflating: flower_photos/test/dandelion/18215579866_94b1732f24.jpg
#   inflating: flower_photos/test/dandelion/18232119726_cef27eaaac_n.jpg
#   inflating: flower_photos/test/dandelion/18238604119_a5689980ee_n.jpg
#   inflating: flower_photos/test/dandelion/18243329421_771b4d938e.jpg
#   inflating: flower_photos/test/dandelion/18243351371_5fda92ac0a_n.jpg
#   inflating: flower_photos/test/dandelion/18271576032_d7e2296de4_n.jpg
#   inflating: flower_photos/test/dandelion/18276105805_d31d3f7e71.jpg
#   inflating: flower_photos/test/dandelion/18282528206_7fb3166041.jpg
#   inflating: flower_photos/test/dandelion/18304194360_2a4a0be631_m.jpg
#   inflating: flower_photos/test/dandelion/18342918441_b1bb69a2fd_n.jpg
#   inflating: flower_photos/test/dandelion/18479635994_83f93f4120.jpg
#   inflating: flower_photos/test/dandelion/18482768066_677292a64e.jpg
#   inflating: flower_photos/test/dandelion/18587334446_ef1021909b_n.jpg
#   inflating: flower_photos/test/dandelion/18687587599_3dd4fdf255.jpg
#   inflating: flower_photos/test/dandelion/18803577858_fd0036e1f5_m.jpg
#   inflating: flower_photos/test/dandelion/18876985840_7531dc8e6a.jpg
#   inflating: flower_photos/test/dandelion/18889216716_cd67aec890_n.jpg
#   inflating: flower_photos/test/dandelion/18970601002_d70bc883a9.jpg
#   inflating: flower_photos/test/dandelion/18995294384_77543e96b6_n.jpg
#   inflating: flower_photos/test/dandelion/18996760154_58d3c48604.jpg
#   inflating: flower_photos/test/dandelion/18996957833_0bd71fbbd4_m.jpg
#   inflating: flower_photos/test/dandelion/18996965033_1d92e5c99e.jpg
#   inflating: flower_photos/test/dandelion/18999743619_cec3f39bee.jpg
#   inflating: flower_photos/test/dandelion/19004688463_12a8423109.jpg
#   inflating: flower_photos/test/dandelion/19064700925_b93d474e37.jpg
#   inflating: flower_photos/test/dandelion/19067907051_16d530c7d2.jpg
#   inflating: flower_photos/test/dandelion/19397467530_1e8131a7cf.jpg
#   inflating: flower_photos/test/dandelion/19426575569_4b53c0b726.jpg
#   inflating: flower_photos/test/dandelion/19435491090_7af558e17e.jpg
#   inflating: flower_photos/test/dandelion/19437578578_6ab1b3c984.jpg
#   inflating: flower_photos/test/dandelion/19437710780_c5f2156438.jpg
#   inflating: flower_photos/test/dandelion/19438516548_bbaf350664.jpg
#   inflating: flower_photos/test/dandelion/19440660848_c789227129_m.jpg
#   inflating: flower_photos/test/dandelion/19440910519_cb1162470e.jpg
#   inflating: flower_photos/test/dandelion/19443674130_08db1d9578_m.jpg
#   inflating: flower_photos/test/dandelion/19443726008_8c9c68efa7_m.jpg
#   inflating: flower_photos/test/dandelion/19506262462_d0945c14a6.jpg
#   inflating: flower_photos/test/dandelion/19526570282_1d1e71b0f3_m.jpg
#   inflating: flower_photos/test/dandelion/19551343814_48f764535f_m.jpg
#   inflating: flower_photos/test/dandelion/19551343954_83bb52f310_m.jpg
#   inflating: flower_photos/test/dandelion/19586799286_beb9d684b5.jpg
#   inflating: flower_photos/test/dandelion/19593576916_f5a083d7fe_n.jpg
#   inflating: flower_photos/test/dandelion/19599413676_fc9ee2640e.jpg
#   inflating: flower_photos/test/dandelion/19600096066_67dc941042.jpg
#   inflating: flower_photos/test/dandelion/19602790836_912d38aaa8.jpg
#   inflating: flower_photos/test/dandelion/19613204505_da554eb56a_n.jpg
#   inflating: flower_photos/test/dandelion/19613308325_a67792d889.jpg
#   inflating: flower_photos/test/dandelion/19617425002_b914c1e2ab.jpg
#   inflating: flower_photos/test/dandelion/19617501581_606be5f716_n.jpg
#   inflating: flower_photos/test/dandelion/19617643201_9922eec796.jpg
#   inflating: flower_photos/test/dandelion/19621170705_30bf8bf0ba.jpg
#   inflating: flower_photos/test/dandelion/19622465055_2a62ebd504_m.jpg
#   inflating: flower_photos/test/dandelion/19626311985_58f1a79da3.jpg
#   inflating: flower_photos/test/dandelion/19691175559_ef12b8b354_n.jpg
#   inflating: flower_photos/test/dandelion/19812060274_c432f603db.jpg
#   inflating: flower_photos/test/dandelion/19961979110_fcd8092388_m.jpg
#   inflating: flower_photos/test/dandelion/20165867412_fc45d31698_m.jpg
#   inflating: flower_photos/test/dandelion/20456824132_b1c8fbfa41_m.jpg
#   inflating: flower_photos/test/dandelion/20754920332_53b995fc63_n.jpg
#   inflating: flower_photos/test/dandelion/20983660733_06b35b9eb8.jpg
#   inflating: flower_photos/test/dandelion/21195621914_a5bdbb203d.jpg
#   inflating: flower_photos/test/dandelion/21523597492_39b6765cd7_m.jpg
#   inflating: flower_photos/test/dandelion/21657726011_2c94e341bc_n.jpg
#   inflating: flower_photos/test/dandelion/22190242684_8c3300d4e6.jpg
#   inflating: flower_photos/test/dandelion/22196426956_eca94f6faa_m.jpg
#   inflating: flower_photos/test/dandelion/22274701614_901606ee34_n.jpg
#   inflating: flower_photos/test/dandelion/22679060358_561ec823ae_m.jpg
#   inflating: flower_photos/test/dandelion/22785985545_95464115b0_m.jpg
#   inflating: flower_photos/test/dandelion/23192507093_2e6ec77bef_n.jpg
#   inflating: flower_photos/test/dandelion/23414449869_ee849a80d4.jpg
#   inflating: flower_photos/test/dandelion/23659122395_3467d88c02_n.jpg
#   inflating: flower_photos/test/dandelion/23891393761_155af6402c.jpg
#   inflating: flower_photos/test/roses/15602874619_03fd934bed.jpg
#   inflating: flower_photos/test/roses/15674450867_0ced942941_n.jpg
#   inflating: flower_photos/test/roses/15681454551_b6f73ce443_n.jpg
#   inflating: flower_photos/test/roses/15697872479_ed48e9dd73_n.jpg
#   inflating: flower_photos/test/roses/15699509054_d3e125286f_n.jpg
#   inflating: flower_photos/test/roses/15712574834_2f121c7cf9_m.jpg
#   inflating: flower_photos/test/roses/15738649506_2b4c2fd933_m.jpg
#   inflating: flower_photos/test/roses/15750320284_22ef21c682.jpg
#   inflating: flower_photos/test/roses/15761264350_4caaf080f6_m.jpg
#   inflating: flower_photos/test/roses/15802657001_40fe77c030_m.jpg
#   inflating: flower_photos/test/roses/15820572326_be2ea4a55c_n.jpg
#   inflating: flower_photos/test/roses/15821959372_518b9dcf57_n.jpg
#   inflating: flower_photos/test/roses/15822837396_96b392fda8_m.jpg
#   inflating: flower_photos/test/roses/15859434664_67bf3ef29f.jpg
#   inflating: flower_photos/test/roses/15901230359_1819e96b89_n.jpg
#   inflating: flower_photos/test/roses/15922772266_1167a06620.jpg
#   inflating: flower_photos/test/roses/15949087094_a8f565295c_m.jpg
#   inflating: flower_photos/test/roses/15951588433_c0713cbfc6_m.jpg
#   inflating: flower_photos/test/roses/15965652160_de91389965_m.jpg
#   inflating: flower_photos/test/roses/15977362155_461030c196_m.jpg
#   inflating: flower_photos/test/roses/15999816377_4b95e0b538_n.jpg
#   inflating: flower_photos/test/roses/16018886851_c32746cb72.jpg
#   inflating: flower_photos/test/roses/16051111039_0f0626a241_n.jpg
#   inflating: flower_photos/test/roses/16078501836_3ac067e18a.jpg
#   inflating: flower_photos/test/roses/16100313047_c2e23cbb3d_n.jpg
#   inflating: flower_photos/test/roses/16149016979_23ef42b642_m.jpg
#   inflating: flower_photos/test/roses/16152175716_55d6968e08_n.jpg
#   inflating: flower_photos/test/roses/16152205512_9d6cb80fb6.jpg
#   inflating: flower_photos/test/roses/16155980245_6ab8d7b888.jpg
#   inflating: flower_photos/test/roses/16157873719_bf0bdf8558_n.jpg
#   inflating: flower_photos/test/roses/16209331331_343c899d38.jpg
#   inflating: flower_photos/test/roses/16229215579_e7dd808e9c.jpg
#   inflating: flower_photos/test/roses/16258946661_f9739cdc0a.jpg
#   inflating: flower_photos/test/roses/16316557109_7fc55c1cbc_m.jpg
#   inflating: flower_photos/test/roses/16334786972_1b3e71cab8_m.jpg
#   inflating: flower_photos/test/roses/16339359979_6d742660b8_n.jpg
#   inflating: flower_photos/test/roses/16374919860_4e445de29f_n.jpg
#   inflating: flower_photos/test/roses/16424992340_c1d9eb72b4.jpg
#   inflating: flower_photos/test/roses/16449467833_d82aac5749_m.jpg
#   inflating: flower_photos/test/roses/16476788181_0e2ffc719a.jpg
#   inflating: flower_photos/test/roses/16484100863_979beacb08.jpg
#   inflating: flower_photos/test/roses/16525204061_9b47be3726_m.jpg
#   inflating: flower_photos/test/roses/16545641666_2781e542a0_m.jpg
#   inflating: flower_photos/test/roses/16552686350_db8db55cd2.jpg
#   inflating: flower_photos/test/roses/16643944275_3cd4cd966c.jpg
#   inflating: flower_photos/test/roses/16666836810_216f50e9c3_m.jpg
#   inflating: flower_photos/test/roses/16670921315_0fc48d7ab2_n.jpg
#   inflating: flower_photos/test/roses/16691277899_9433f39155_n.jpg
#   inflating: flower_photos/test/roses/16772483324_09f24813a1_n.jpg
#   inflating: flower_photos/test/roses/16903172207_2cd7aca66a.jpg
#   inflating: flower_photos/test/roses/16961613890_695b36aab2_m.jpg
#   inflating: flower_photos/test/roses/17040847367_b54d05bf52.jpg
#   inflating: flower_photos/test/roses/17051448596_69348f7fce_m.jpg
#   inflating: flower_photos/test/roses/17062080069_36ac7907d2_n.jpg
#   inflating: flower_photos/test/roses/17077876795_6dd1b03f54_m.jpg
#   inflating: flower_photos/test/roses/17090993740_fcc8b60b81.jpg
#   inflating: flower_photos/test/roses/17158274118_00ec99a23c.jpg
#   inflating: flower_photos/test/roses/17165596357_392a12391f.jpg
#   inflating: flower_photos/test/roses/17302463621_d82be11f01_n.jpg
#   inflating: flower_photos/test/roses/17305246720_1866d6303b.jpg
#   inflating: flower_photos/test/roses/17449165090_dfb27af360_n.jpg
#   inflating: flower_photos/test/roses/17554868955_35f48516cd_m.jpg
#   inflating: flower_photos/test/roses/17700322054_1c4fdaa034_m.jpg
#   inflating: flower_photos/test/roses/17702388233_f29dc14834_m.jpg
#   inflating: flower_photos/test/roses/17953368844_be3d18cf30_m.jpg
#   inflating: flower_photos/test/roses/17990320484_93bba345d2_m.jpg
#   inflating: flower_photos/test/roses/18220342690_f1c20134bd.jpg
#   inflating: flower_photos/test/roses/18376177250_86060cbdc9.jpg
#   inflating: flower_photos/test/roses/18389368680_91c24a2087_z.jpg
#   inflating: flower_photos/test/roses/18563353954_b761d97155_m.jpg
#   inflating: flower_photos/test/roses/18584002386_cec0df537d_n.jpg
#   inflating: flower_photos/test/roses/18599603859_f2ec616ddf_n.jpg
#   inflating: flower_photos/test/roses/18741313803_1bbf842fc6_n.jpg
#   inflating: flower_photos/test/roses/18760363474_a707331322_n.jpg
#   inflating: flower_photos/test/roses/18990187093_09f2bff8fc_m.jpg
#   inflating: flower_photos/test/roses/19153732586_9de58c8f53_n.jpg
#   inflating: flower_photos/test/roses/19271410704_932d1f2c97_n.jpg
#   inflating: flower_photos/test/roses/19440805164_920b28da61_n.jpg
#   inflating: flower_photos/test/roses/19566556880_476c66c5ee_n.jpg
#   inflating: flower_photos/test/roses/19823402005_2db025dd66_m.jpg
#   inflating: flower_photos/test/roses/19919867648_043cf02fc3.jpg
#   inflating: flower_photos/test/roses/19988406792_68201f76e3_n.jpg
#   inflating: flower_photos/test/roses/20409866779_ac473f55e0_m.jpg
#   inflating: flower_photos/test/roses/20596941736_f2c5f496cf.jpg
#   inflating: flower_photos/test/roses/20622485918_90fc000c86_n.jpg
#   inflating: flower_photos/test/roses/20825078671_90b0389c70_m.jpg
#   inflating: flower_photos/test/roses/21346056089_e6f8074e5f_m.jpg
#   inflating: flower_photos/test/roses/21347496068_f4d3339607.jpg
#   inflating: flower_photos/test/roses/21413573151_e681c6a97a.jpg
#   inflating: flower_photos/test/roses/21522100663_455b77a90c_n.jpg
#   inflating: flower_photos/test/roses/22093190909_77223e6f53_n.jpg
#   inflating: flower_photos/test/sunflowers/15243175532_ac28c48e14_m.jpg
#   inflating: flower_photos/test/sunflowers/15266715291_dfa3f1d49f_n.jpg
#   inflating: flower_photos/test/sunflowers/15380755137_a2e67839ab_m.jpg
#   inflating: flower_photos/test/sunflowers/15460162172_014bcce403.jpg
#   inflating: flower_photos/test/sunflowers/15472217046_2699b25584.jpg
#   inflating: flower_photos/test/sunflowers/15493195788_60530f2398_m.jpg
#   inflating: flower_photos/test/sunflowers/15495578821_92c6d14252_n.jpg
#   inflating: flower_photos/test/sunflowers/15495579081_661cb260d1_n.jpg
#   inflating: flower_photos/test/sunflowers/15683877266_42e0fe3782_n.jpg
#   inflating: flower_photos/test/sunflowers/15745084272_36402f5ee6_n.jpg
#   inflating: flower_photos/test/sunflowers/15839183375_49bf4f75e8_m.jpg
#   inflating: flower_photos/test/sunflowers/15973657966_d6f6005539_n.jpg
#   inflating: flower_photos/test/sunflowers/16143151468_4f3c033e33.jpg
#   inflating: flower_photos/test/sunflowers/16616096711_12375a0260_n.jpg
#   inflating: flower_photos/test/sunflowers/16656015339_2ccb7cd18d.jpg
#   inflating: flower_photos/test/sunflowers/16832961488_5f7e70eb5e_n.jpg
#   inflating: flower_photos/test/sunflowers/16967372357_15b1b9a812_n.jpg
#   inflating: flower_photos/test/sunflowers/16975010069_7afd290657_m.jpg
#   inflating: flower_photos/test/sunflowers/16988605969_570329ff20_n.jpg
#   inflating: flower_photos/test/sunflowers/17148843706_df148301ac_n.jpg
#   inflating: flower_photos/test/sunflowers/17433282043_441b0a07f4_n.jpg
#   inflating: flower_photos/test/sunflowers/18097401209_910a46fae1_n.jpg
#   inflating: flower_photos/test/sunflowers/18237156988_9ceb46a8de_n.jpg
#   inflating: flower_photos/test/sunflowers/18237215308_a158d49f28_n.jpg
#   inflating: flower_photos/test/sunflowers/18250039435_7654bc11be_n.jpg
#   inflating: flower_photos/test/sunflowers/18766965343_9f42d4bedc_m.jpg
#   inflating: flower_photos/test/sunflowers/18828277053_1493158b28.jpg
#   inflating: flower_photos/test/sunflowers/18828283553_e46504ae38.jpg
#   inflating: flower_photos/test/sunflowers/18843967474_9cb552716b.jpg
#   inflating: flower_photos/test/sunflowers/18972803569_1a0634f398_m.jpg
#   inflating: flower_photos/test/sunflowers/19349582128_68a662075e_n.jpg
#   inflating: flower_photos/test/sunflowers/19359539074_d7e32e6616_n.jpg
#   inflating: flower_photos/test/sunflowers/19442589512_e733cfea0f.jpg
#   inflating: flower_photos/test/sunflowers/19453165201_2aa747e0bf.jpg
#   inflating: flower_photos/test/sunflowers/19504937128_a4ae90fcbd_m.jpg
#   inflating: flower_photos/test/sunflowers/19508264965_d1dfb565ea_n.jpg
#   inflating: flower_photos/test/sunflowers/19519101829_46af0b4547_m.jpg
#   inflating: flower_photos/test/sunflowers/19595718862_c68896370c_m.jpg
#   inflating: flower_photos/test/sunflowers/19697910486_0086d893a2.jpg
#   inflating: flower_photos/test/sunflowers/19710076021_f5bb162540.jpg
#   inflating: flower_photos/test/sunflowers/19710925313_31682fa22b_m.jpg
#   inflating: flower_photos/test/sunflowers/19756232959_17cde3b9f0_m.jpg
#   inflating: flower_photos/test/sunflowers/19784656639_cd7f0a4a26_m.jpg
#   inflating: flower_photos/test/sunflowers/19915160340_ec904edbdf_n.jpg
#   inflating: flower_photos/test/sunflowers/20022771089_3cc7e5086d_m.jpg
#   inflating: flower_photos/test/sunflowers/20078409301_aa8061bd0b_n.jpg
#   inflating: flower_photos/test/sunflowers/20148493928_9f75a99783.jpg
#   inflating: flower_photos/test/sunflowers/20156280765_a6baea3176.jpg
#   inflating: flower_photos/test/sunflowers/20171662239_f69b6c12bd_n.jpg
#   inflating: flower_photos/test/sunflowers/20183028616_beb937e75c_m.jpg
#   inflating: flower_photos/test/sunflowers/20183071136_c297e74fcc_m.jpg
#   inflating: flower_photos/test/sunflowers/20258015499_93b9951800_m.jpg
#   inflating: flower_photos/test/sunflowers/20342824594_9740b7b160.jpg
#   inflating: flower_photos/test/sunflowers/20344282483_05abb0b837.jpg
#   inflating: flower_photos/test/sunflowers/20344366953_44fb51051b.jpg
#   inflating: flower_photos/test/sunflowers/20406385204_469f6749e2_n.jpg
#   inflating: flower_photos/test/sunflowers/20407896403_a50fef58ac_n.jpg
#   inflating: flower_photos/test/sunflowers/20410533613_56da1cce7c.jpg
#   inflating: flower_photos/test/sunflowers/20410697750_c43973d1eb.jpg
#   inflating: flower_photos/test/sunflowers/20481273479_d459834a3e_n.jpg
#   inflating: flower_photos/test/sunflowers/20621698991_dcb323911d.jpg
#   inflating: flower_photos/test/sunflowers/20658775992_1619cd0a9b_n.jpg
#   inflating: flower_photos/test/sunflowers/20667988875_6e73ac2879_n.jpg
#   inflating: flower_photos/test/sunflowers/20704967595_a9c9b8d431.jpg
#   inflating: flower_photos/test/sunflowers/20753711039_0b11d24b50_n.jpg
#   inflating: flower_photos/test/sunflowers/20777358950_c63ea569a1.jpg
#   inflating: flower_photos/test/sunflowers/20777375650_ef854bf645.jpg
#   inflating: flower_photos/test/sunflowers/20871601265_daa4be4291_n.jpg
#   inflating: flower_photos/test/sunflowers/20905163782_312e2c3bda_n.jpg
#   inflating: flower_photos/test/sunflowers/20965412955_2c640b13bd.jpg
#   inflating: flower_photos/test/sunflowers/20972862281_5367f4af88.jpg
#   inflating: flower_photos/test/sunflowers/20972866151_e6a928b00a.jpg
#   inflating: flower_photos/test/sunflowers/21134000558_d7d6c9b1fe_n.jpg
#   inflating: flower_photos/test/sunflowers/21349789961_18ba1af5b7_n.jpg
#   inflating: flower_photos/test/sunflowers/21374127408_5ffbe87bb2.jpg
#   inflating: flower_photos/test/sunflowers/21518663809_3d69f5b995_n.jpg
#   inflating: flower_photos/test/sunflowers/21728822928_9f6817325a_n.jpg
#   inflating: flower_photos/test/sunflowers/21796333524_38fc8e0ab5_n.jpg
#   inflating: flower_photos/test/sunflowers/21821266773_7113d34c35_m.jpg
#   inflating: flower_photos/test/sunflowers/21984860006_20dfacea1c_m.jpg
#   inflating: flower_photos/test/sunflowers/21995435890_e5672244a4_m.jpg
#   inflating: flower_photos/test/sunflowers/22183521655_56221bf2a4_n.jpg
#   inflating: flower_photos/test/sunflowers/22183529245_ce13557515_m.jpg
#   inflating: flower_photos/test/sunflowers/22203670478_9ec5c2700b_n.jpg
#   inflating: flower_photos/test/sunflowers/22255608949_172d7c8d22_m.jpg
#   inflating: flower_photos/test/sunflowers/22405882322_d4561f8469_n.jpg
#   inflating: flower_photos/test/sunflowers/22405887122_75eda1872f_m.jpg
#   inflating: flower_photos/test/sunflowers/22416421196_caf131c9fa_m.jpg
#   inflating: flower_photos/test/sunflowers/22419079265_8902cddb7d_n.jpg
#   inflating: flower_photos/test/sunflowers/22429146402_332fa2fc72_m.jpg
#   inflating: flower_photos/test/sunflowers/22429946721_e17a12cb39_n.jpg
#   inflating: flower_photos/test/sunflowers/22478719251_276cb094f9_n.jpg
#   inflating: flower_photos/test/sunflowers/22686342422_c0b9e2f38e.jpg
#   inflating: flower_photos/test/sunflowers/22755811033_cd17b109e0.jpg
#   inflating: flower_photos/test/sunflowers/22992257000_76dbc599e7_m.jpg
#   inflating: flower_photos/test/sunflowers/23204123212_ef32fbafbe.jpg
#   inflating: flower_photos/test/sunflowers/23247483352_0defc7a6dc_n.jpg
#   inflating: flower_photos/test/sunflowers/23286304156_3635f7de05.jpg
#   inflating: flower_photos/test/sunflowers/23356825566_f5885875f2.jpg
#   inflating: flower_photos/test/sunflowers/23645265812_24352ff6bf.jpg
#   inflating: flower_photos/test/sunflowers/23894449029_bf0f34d35d_n.jpg
#   inflating: flower_photos/test/tulips/14487762578_baba13d16a_m.jpg
#   inflating: flower_photos/test/tulips/14487943607_651e8062a1_m.jpg
#   inflating: flower_photos/test/tulips/14491997336_36ba524713.jpg
#   inflating: flower_photos/test/tulips/14651383746_419dc73634_m.jpg
#   inflating: flower_photos/test/tulips/14651385476_7ccb20e594_m.jpg
#   inflating: flower_photos/test/tulips/14671196461_b725727229_m.jpg
#   inflating: flower_photos/test/tulips/14674067742_73c2602aa6_m.jpg
#   inflating: flower_photos/test/tulips/14674071872_2df55466d5_m.jpg
#   inflating: flower_photos/test/tulips/14674388855_2da18e375a_m.jpg
#   inflating: flower_photos/test/tulips/14674389605_df3c0bcfa1_m.jpg
#   inflating: flower_photos/test/tulips/14746916178_40403cc57e.jpg
#   inflating: flower_photos/test/tulips/14836105101_1d07520932_m.jpg
#   inflating: flower_photos/test/tulips/14861513337_4ef0bfa40d.jpg
#   inflating: flower_photos/test/tulips/14866400927_3a59899df3_m.jpg
#   inflating: flower_photos/test/tulips/15029962436_3e50c1f30f_n.jpg
#   inflating: flower_photos/test/tulips/15049902081_dd85361f8c_m.jpg
#   inflating: flower_photos/test/tulips/15052586652_56a82de133_m.jpg
#   inflating: flower_photos/test/tulips/15082212714_ff87e8fcb1_m.jpg
#   inflating: flower_photos/test/tulips/15090146325_b7e1249e60.jpg
#   inflating: flower_photos/test/tulips/15147464747_594599c855_m.jpg
#   inflating: flower_photos/test/tulips/15147473067_7c5498eb0e_m.jpg
#   inflating: flower_photos/test/tulips/15149373026_93aacc65c5.jpg
#   inflating: flower_photos/test/tulips/15275144259_f9a18ec9cb.jpg
#   inflating: flower_photos/test/tulips/15275190769_0ed7bbf490.jpg
#   inflating: flower_photos/test/tulips/15275199229_962387f24d.jpg
#   inflating: flower_photos/test/tulips/15275478257_fbd5850708_n.jpg
#   inflating: flower_photos/test/tulips/15275504998_ca9eb82998.jpg
#   inflating: flower_photos/test/tulips/15452909878_0c4941f729_m.jpg
#   inflating: flower_photos/test/tulips/15458787091_3edc6cd1eb.jpg
#   inflating: flower_photos/test/tulips/15516715153_08abc9bb20_n.jpg
#   inflating: flower_photos/test/tulips/15516736553_b169b67195_n.jpg
#   inflating: flower_photos/test/tulips/15632065904_0d9caf174b.jpg
#   inflating: flower_photos/test/tulips/15647243236_2778501cf5_n.jpg
#   inflating: flower_photos/test/tulips/15756524087_823cf86bd8_m.jpg
#   inflating: flower_photos/test/tulips/15881325303_f00807a051_n.jpg
#   inflating: flower_photos/test/tulips/15922772266_1167a06620.jpg
#   inflating: flower_photos/test/tulips/15976769174_1d50f46ca1_m.jpg
#   inflating: flower_photos/test/tulips/16055807744_000bc07afc_m.jpg
#   inflating: flower_photos/test/tulips/16062072523_1be3c0b61f.jpg
#   inflating: flower_photos/test/tulips/16074109313_2cc14c7d16.jpg
#   inflating: flower_photos/test/tulips/16098264209_38fe491093.jpg
#   inflating: flower_photos/test/tulips/16110795216_b3e44697b4_m.jpg
#   inflating: flower_photos/test/tulips/16138212287_643bf336e1_m.jpg
#   inflating: flower_photos/test/tulips/16139439153_fbdee29a10_n.jpg
#   inflating: flower_photos/test/tulips/16169741783_deeab1a679_m.jpg
#   inflating: flower_photos/test/tulips/16265876844_0a149c4f76.jpg
#   inflating: flower_photos/test/tulips/16265883604_92be82b973.jpg
#   inflating: flower_photos/test/tulips/16282277874_b92776b194.jpg
#   inflating: flower_photos/test/tulips/16283125269_4cfae953f1.jpg
#   inflating: flower_photos/test/tulips/16303377824_6e9128b4bd.jpg
#   inflating: flower_photos/test/tulips/16309287412_5cc4d58bd1_n.jpg
#   inflating: flower_photos/test/tulips/16471277547_a0a5509377_n.jpg
#   inflating: flower_photos/test/tulips/16485607329_e66d5960bc_m.jpg
#   inflating: flower_photos/test/tulips/16506668270_b823935dc3.jpg
#   inflating: flower_photos/test/tulips/16582481123_06e8e6b966_n.jpg
#   inflating: flower_photos/test/tulips/16594995743_ce72c61201_n.jpg
#   inflating: flower_photos/test/tulips/16644790896_7b296ecd67_n.jpg
#   inflating: flower_photos/test/tulips/16645809126_613b1e3ebe_m.jpg
#   inflating: flower_photos/test/tulips/16670377091_87987f50a4_n.jpg
#   inflating: flower_photos/test/tulips/16677199221_eab3f22378_n.jpg
#   inflating: flower_photos/test/tulips/16677542612_a78a8ca8b3_m.jpg
#   inflating: flower_photos/test/tulips/16680927427_07ca6e4552_n.jpg
#   inflating: flower_photos/test/tulips/16680930777_7e7f292fc5_n.jpg
#   inflating: flower_photos/test/tulips/16680998737_6f6225fe36.jpg
#   inflating: flower_photos/test/tulips/16700863150_ddaa4d89b4_n.jpg
#   inflating: flower_photos/test/tulips/16702117379_c25bff70e9.jpg
#   inflating: flower_photos/test/tulips/16702188449_3dacce90b2_m.jpg
#   inflating: flower_photos/test/tulips/16711791713_e54bc9c1af_n.jpg
#   inflating: flower_photos/test/tulips/16717320956_d4b00807f2.jpg
#   inflating: flower_photos/test/tulips/16732302779_8aa56f255d_n.jpg
#   inflating: flower_photos/test/tulips/16751015081_af2ef77c9a_n.jpg
#   inflating: flower_photos/test/tulips/16765283686_0315ae00a8.jpg
#   inflating: flower_photos/test/tulips/16862349256_0a1f91ab53.jpg
#   inflating: flower_photos/test/tulips/16862351376_f0fcc6fc91_n.jpg
#   inflating: flower_photos/test/tulips/16862374316_4135908d4c_m.jpg
#   inflating: flower_photos/test/tulips/16862422576_5226e8d1d0.jpg
#   inflating: flower_photos/test/tulips/16904202259_8f45d045c3_m.jpg
#   inflating: flower_photos/test/tulips/16907559551_05ded87fb2_n.jpg
#   inflating: flower_photos/test/tulips/16930105456_8b826dc4a8_n.jpg
#   inflating: flower_photos/test/tulips/16930121391_a4092ecf00_n.jpg
#   inflating: flower_photos/test/tulips/16937554595_3e1de22f9c.jpg
#   inflating: flower_photos/test/tulips/16938892686_3613ea68e8_n.jpg
#   inflating: flower_photos/test/tulips/16951623209_00fb7ec1b1_n.jpg
#   inflating: flower_photos/test/tulips/16986144192_55e0e6c152.jpg
#   inflating: flower_photos/test/tulips/17012955700_7141d29eee.jpg
#   inflating: flower_photos/test/tulips/17066862602_7530f21efe.jpg
#   inflating: flower_photos/test/tulips/17066864992_1cbc4fc908.jpg
#   inflating: flower_photos/test/tulips/17078576150_6f272ce73f_n.jpg
#   inflating: flower_photos/test/tulips/17078716890_68e0723389_n.jpg
#   inflating: flower_photos/test/tulips/17094167287_865840060d_n.jpg
#   inflating: flower_photos/test/tulips/17146928665_600fa3a1f1_n.jpg
#   inflating: flower_photos/test/tulips/17159349572_c0c51599f7_n.jpg
#   inflating: flower_photos/test/tulips/17159816388_deafbebdb0.jpg
#   inflating: flower_photos/test/tulips/17165583356_38cb1f231d_n.jpg
#   inflating: flower_photos/test/tulips/17167151059_a53bfe0b02.jpg
#   inflating: flower_photos/test/tulips/17189456156_6fc1067831.jpg
#   inflating: flower_photos/test/tulips/17189526216_fa24dd541a_n.jpg
#   inflating: flower_photos/test/tulips/17198868382_697b23c715_n.jpg
#   inflating: flower_photos/test/tulips/17199496791_3caaf5e278_m.jpg
#   inflating: flower_photos/test/tulips/17199499591_67b64b21ed_m.jpg
#   inflating: flower_photos/test/tulips/17202535346_ab828e779b.jpg
#   inflating: flower_photos/test/tulips/17224410762_402455ed8f.jpg
#   inflating: flower_photos/test/tulips/17282288501_e8738c9cfb_n.jpg
#   inflating: flower_photos/test/tulips/17295127995_62eff434fe_n.jpg
#   inflating: flower_photos/test/tulips/17309951996_552d632cbb_n.jpg
#   inflating: flower_photos/test/tulips/17318339476_54479b6660_n.jpg
#   inflating: flower_photos/test/tulips/17324469461_2b318aff8d_m.jpg
#   inflating: flower_photos/test/tulips/17408197905_829c4d7940_m.jpg
#   inflating: flower_photos/test/tulips/17469578564_35a8360f58.jpg
#   inflating: flower_photos/test/tulips/17719248689_cfd5d2f228_n.jpg
#   inflating: flower_photos/test/tulips/17720403638_94cfcd8d5c_n.jpg
#   inflating: flower_photos/test/tulips/17781940352_a45e4289a5.jpg
#   inflating: flower_photos/test/tulips/17844723633_da85357fe3.jpg
#   inflating: flower_photos/test/tulips/17862445825_f7031d6f26.jpg
#   inflating: flower_photos/test/tulips/17907238905_1ae121f8d9_m.jpg
#   inflating: flower_photos/test/tulips/17908793211_ff0f1f81d3_n.jpg
#   inflating: flower_photos/test/tulips/17994129033_bbd0acba62_n.jpg
#   inflating: flower_photos/test/tulips/18245124970_e68fd3f3c3.jpg
#   inflating: flower_photos/test/tulips/18270448366_d5676dec64_z.jpg
#   inflating: flower_photos/test/tulips/18378581986_5cd1494d08_n.jpg
#   inflating: flower_photos/test/tulips/18378582936_ee7085c850.jpg
#   inflating: flower_photos/test/tulips/18406629611_4d1edcf23b_n.jpg
#   inflating: flower_photos/test/tulips/19413898445_69344f9956_n.jpg
#   inflating: flower_photos/test/tulips/19425920580_cdc8f49aed_n.jpg
#   inflating: flower_photos/train/.DS_Store
#   inflating: __MACOSX/flower_photos/train/._.DS_Store
#   inflating: flower_photos/train/daisy/.DS_Store
#   inflating: __MACOSX/flower_photos/train/daisy/._.DS_Store
#   inflating: flower_photos/train/daisy/100080576_f52e8ee070_n.jpg
#   inflating: flower_photos/train/daisy/10140303196_b88d3d6cec.jpg
#   inflating: flower_photos/train/daisy/10172379554_b296050f82_n.jpg
#   inflating: flower_photos/train/daisy/10172567486_2748826a8b.jpg
#   inflating: flower_photos/train/daisy/10172636503_21bededa75_n.jpg
#   inflating: flower_photos/train/daisy/102841525_bd6628ae3c.jpg
#   inflating: flower_photos/train/daisy/1031799732_e7f4008c03.jpg
#   inflating: flower_photos/train/daisy/10391248763_1d16681106_n.jpg
#   inflating: flower_photos/train/daisy/10437754174_22ec990b77_m.jpg
#   inflating: flower_photos/train/daisy/10437770546_8bb6f7bdd3_m.jpg
#   inflating: flower_photos/train/daisy/10437929963_bc13eebe0c.jpg
#   inflating: flower_photos/train/daisy/10466290366_cc72e33532.jpg
#   inflating: flower_photos/train/daisy/10466558316_a7198b87e2.jpg
#   inflating: flower_photos/train/daisy/10555749515_13a12a026e.jpg
#   inflating: flower_photos/train/daisy/10555815624_dc211569b0.jpg
#   inflating: flower_photos/train/daisy/10555826524_423eb8bf71_n.jpg
#   inflating: flower_photos/train/daisy/10559679065_50d2b16f6d.jpg
#   inflating: flower_photos/train/daisy/105806915_a9c13e2106_n.jpg
#   inflating: flower_photos/train/daisy/10712722853_5632165b04.jpg
#   inflating: flower_photos/train/daisy/107592979_aaa9cdfe78_m.jpg
#   inflating: flower_photos/train/daisy/10770585085_4742b9dac3_n.jpg
#   inflating: flower_photos/train/daisy/10841136265_af473efc60.jpg
#   inflating: flower_photos/train/daisy/10993710036_2033222c91.jpg
#   inflating: flower_photos/train/daisy/10993818044_4c19b86c82.jpg
#   inflating: flower_photos/train/daisy/10994032453_ac7f8d9e2e.jpg
#   inflating: flower_photos/train/daisy/11023214096_b5b39fab08.jpg
#   inflating: flower_photos/train/daisy/11023272144_fce94401f2_m.jpg
#   inflating: flower_photos/train/daisy/11023277956_8980d53169_m.jpg
#   inflating: flower_photos/train/daisy/11124324295_503f3a0804.jpg
#   inflating: flower_photos/train/daisy/1140299375_3aa7024466.jpg
#   inflating: flower_photos/train/daisy/11439894966_dca877f0cd.jpg
#   inflating: flower_photos/train/daisy/1150395827_6f94a5c6e4_n.jpg
#   inflating: flower_photos/train/daisy/11642632_1e7627a2cc.jpg
#   inflating: flower_photos/train/daisy/11834945233_a53b7a92ac_m.jpg
#   inflating: flower_photos/train/daisy/11870378973_2ec1919f12.jpg
#   inflating: flower_photos/train/daisy/11891885265_ccefec7284_n.jpg
#   inflating: flower_photos/train/daisy/12193032636_b50ae7db35_n.jpg
#   inflating: flower_photos/train/daisy/12348343085_d4c396e5b5_m.jpg
#   inflating: flower_photos/train/daisy/12585131704_0f64b17059_m.jpg
#   inflating: flower_photos/train/daisy/12601254324_3cb62c254a_m.jpg
#   inflating: flower_photos/train/daisy/1265350143_6e2b276ec9.jpg
#   inflating: flower_photos/train/daisy/12701063955_4840594ea6_n.jpg
#   inflating: flower_photos/train/daisy/1285423653_18926dc2c8_n.jpg
#   inflating: flower_photos/train/daisy/1286274236_1d7ac84efb_n.jpg
#   inflating: flower_photos/train/daisy/12891819633_e4c82b51e8.jpg
#   inflating: flower_photos/train/daisy/1299501272_59d9da5510_n.jpg
#   inflating: flower_photos/train/daisy/1306119996_ab8ae14d72_n.jpg
#   inflating: flower_photos/train/daisy/1314069875_da8dc023c6_m.jpg
#   inflating: flower_photos/train/daisy/1342002397_9503c97b49.jpg
#   inflating: flower_photos/train/daisy/134372449_0f7166d96c_n.jpg
#   inflating: flower_photos/train/daisy/134409839_71069a95d1_m.jpg
#   inflating: flower_photos/train/daisy/1344985627_c3115e2d71_n.jpg
#   inflating: flower_photos/train/daisy/13491959645_2cd9df44d6_n.jpg
#   inflating: flower_photos/train/daisy/1354396826_2868631432_m.jpg
#   inflating: flower_photos/train/daisy/1355787476_32e9f2a30b.jpg
#   inflating: flower_photos/train/daisy/13583238844_573df2de8e_m.jpg
#   inflating: flower_photos/train/daisy/1374193928_a52320eafa.jpg
#   inflating: flower_photos/train/daisy/13826249325_f61cb15f86_n.jpg
#   inflating: flower_photos/train/daisy/13901930939_a7733c03f0_n.jpg
#   inflating: flower_photos/train/daisy/1392131677_116ec04751.jpg
#   inflating: flower_photos/train/daisy/1392946544_115acbb2d9.jpg
#   inflating: flower_photos/train/daisy/13953307149_f8de6a768c_m.jpg
#   inflating: flower_photos/train/daisy/1396526833_fb867165be_n.jpg
#   inflating: flower_photos/train/daisy/13977181862_f8237b6b52.jpg
#   inflating: flower_photos/train/daisy/14021430525_e06baf93a9.jpg
#   inflating: flower_photos/train/daisy/14073784469_ffb12f3387_n.jpg
#   inflating: flower_photos/train/daisy/14087947408_9779257411_n.jpg
#   inflating: flower_photos/train/daisy/14088053307_1a13a0bf91_n.jpg
#   inflating: flower_photos/train/daisy/14114116486_0bb6649bc1_m.jpg
#   inflating: flower_photos/train/daisy/14147016029_8d3cf2414e.jpg
#   inflating: flower_photos/train/daisy/14163875973_467224aaf5_m.jpg
#   inflating: flower_photos/train/daisy/14167534527_781ceb1b7a_n.jpg
#   inflating: flower_photos/train/daisy/14167543177_cd36b54ac6_n.jpg
#   inflating: flower_photos/train/daisy/14219214466_3ca6104eae_m.jpg
#   inflating: flower_photos/train/daisy/14221836990_90374e6b34.jpg
#   inflating: flower_photos/train/daisy/14221848160_7f0a37c395.jpg
#   inflating: flower_photos/train/daisy/14245834619_153624f836.jpg
#   inflating: flower_photos/train/daisy/14264136211_9531fbc144.jpg
#   inflating: flower_photos/train/daisy/14272874304_47c0a46f5a.jpg
#   inflating: flower_photos/train/daisy/14307766919_fac3c37a6b_m.jpg
#   inflating: flower_photos/train/daisy/14330343061_99478302d4_m.jpg
#   inflating: flower_photos/train/daisy/144076848_57e1d662e3_m.jpg
#   inflating: flower_photos/train/daisy/144099102_bf63a41e4f_n.jpg
#   inflating: flower_photos/train/daisy/1441939151_b271408c8d_n.jpg
#   inflating: flower_photos/train/daisy/144603918_b9de002f60_m.jpg
#   inflating: flower_photos/train/daisy/147068564_32bb4350cc.jpg
#   inflating: flower_photos/train/daisy/15207766_fc2f1d692c_n.jpg
#   inflating: flower_photos/train/daisy/153210866_03cc9f2f36.jpg
#   inflating: flower_photos/train/daisy/154332674_453cea64f4.jpg
#   inflating: flower_photos/train/daisy/158869618_f1a6704236_n.jpg
#   inflating: flower_photos/train/daisy/162362896_99c7d851c8_n.jpg
#   inflating: flower_photos/train/daisy/162362897_1d21b70621_m.jpg
#   inflating: flower_photos/train/daisy/163978992_8128b49d3e_n.jpg
#   inflating: flower_photos/train/daisy/1656856503_447e5b0f03.jpg
#   inflating: flower_photos/train/daisy/169371301_d9b91a2a42.jpg
#   inflating: flower_photos/train/daisy/171972704_389cf7a953.jpg
#   inflating: flower_photos/train/daisy/172882635_4cc7b86731_m.jpg
#   inflating: flower_photos/train/daisy/172967318_c596d082cc.jpg
#   inflating: flower_photos/train/daisy/173350276_02817aa8d5.jpg
#   inflating: flower_photos/train/daisy/174131220_c853df1287.jpg
#   inflating: flower_photos/train/daisy/175106495_53ebdef092_n.jpg
#   inflating: flower_photos/train/daisy/176375506_201859bb92_m.jpg
#   inflating: flower_photos/train/daisy/181007802_7cab5ee78e_n.jpg
#   inflating: flower_photos/train/daisy/1879567877_8ed2a5faa7_n.jpg
#   inflating: flower_photos/train/daisy/1955336401_fbb206d6ef_n.jpg
#   inflating: flower_photos/train/daisy/2001380507_19488ff96a_n.jpg
#   inflating: flower_photos/train/daisy/2019064575_7656b9340f_m.jpg
#   inflating: flower_photos/train/daisy/2045022175_ad087f5f60_n.jpg
#   inflating: flower_photos/train/daisy/2057816617_18448093d0_n.jpg
#   inflating: flower_photos/train/daisy/2077865117_9ed85191ae_n.jpg
#   inflating: flower_photos/train/daisy/2087343668_ef4fb95787_n.jpg
#   inflating: flower_photos/train/daisy/21652746_cc379e0eea_m.jpg
#   inflating: flower_photos/train/daisy/2213954589_c7da4b1486.jpg
#   inflating: flower_photos/train/daisy/2331133004_582772d58f_m.jpg
#   inflating: flower_photos/train/daisy/2346726545_2ebce2b2a6.jpg
#   inflating: flower_photos/train/daisy/2349640101_212c275aa7.jpg
#   inflating: flower_photos/train/daisy/2351206867_084e57bd97.jpg
#   inflating: flower_photos/train/daisy/2365428551_39f83f10bf_n.jpg
#   inflating: flower_photos/train/daisy/2408024540_37f0be7cc0_n.jpg
#   inflating: flower_photos/train/daisy/2454280135_ac3aa75cdc_n.jpg
#   inflating: flower_photos/train/daisy/2454280137_e1637536ae_n.jpg
#   inflating: flower_photos/train/daisy/2473825306_62fd5f8785_n.jpg
#   inflating: flower_photos/train/daisy/2476937534_21b285aa46_n.jpg
#   inflating: flower_photos/train/daisy/2479956481_8d1a9699be_n.jpg
# ...
#   inflating: flower_photos/train/tulips/5635348214_a4e2b19ffe.jpg
#   inflating: flower_photos/train/tulips/5637140035_e6c5514f54.jpg
#   inflating: flower_photos/train/tulips/5644061265_e02135f028_n.jpg
#   inflating: flower_photos/train/tulips/5653364300_bc557236c7_n.jpg
#   inflating: flower_photos/train/tulips/5661431592_cea1108261_n.jpg
#   inflating: flower_photos/train/tulips/5665080897_0796f726c9_m.jpg
#   inflating: flower_photos/train/tulips/5665708521_799585d229_n.jpg
#   inflating: flower_photos/train/tulips/5666286130_1dc6f66f09_n.jpg
#   inflating: flower_photos/train/tulips/5670916806_df4316006f_n.jpg
#   inflating: flower_photos/train/tulips/5674125303_953b0ecf38.jpg
#   inflating: flower_photos/train/tulips/5674127693_1ddbd81097.jpg
#   inflating: flower_photos/train/tulips/5674132053_b40a7d32ca.jpg
#   inflating: flower_photos/train/tulips/5674134129_2db5136cba.jpg
#   inflating: flower_photos/train/tulips/5674167473_ac696c8989_n.jpg
#   inflating: flower_photos/train/tulips/5674170543_73e3f403fb.jpg
#   inflating: flower_photos/train/tulips/5674695558_61397a1584.jpg
#   inflating: flower_photos/train/tulips/5674704952_9bd225ed9e_n.jpg
#   inflating: flower_photos/train/tulips/5674707464_dc18de05b1.jpg
#   inflating: flower_photos/train/tulips/5680695867_baff72fc7c.jpg
#   inflating: flower_photos/train/tulips/5682463466_d3e641cb8b.jpg
#   inflating: flower_photos/train/tulips/5687705933_55a8c2dbac.jpg
#   inflating: flower_photos/train/tulips/5691090657_2f1e9bf49e_n.jpg
#   inflating: flower_photos/train/tulips/5691100579_4a2767360a.jpg
#   inflating: flower_photos/train/tulips/5691672942_70a93d70fc.jpg
#   inflating: flower_photos/train/tulips/5697471591_200ff951fa_n.jpg
#   inflating: flower_photos/train/tulips/5698944116_fd35fe6bea.jpg
#   inflating: flower_photos/train/tulips/5700394524_dc6f8fa9cd_n.jpg
#   inflating: flower_photos/train/tulips/5700466891_2bcb17fa68_n.jpg
#   inflating: flower_photos/train/tulips/5704726114_a92f753514.jpg
#   inflating: flower_photos/train/tulips/5716293002_a8be6a6dd3_n.jpg
#   inflating: flower_photos/train/tulips/5718781677_d5e9267115_n.jpg
#   inflating: flower_photos/train/tulips/5719416820_3060e3c1f0.jpg
#   inflating: flower_photos/train/tulips/5730908127_da871df0f8.jpg
#   inflating: flower_photos/train/tulips/5738195260_b3fc107aa7_n.jpg
#   inflating: flower_photos/train/tulips/574373182_2776669a79_n.jpg
#   inflating: flower_photos/train/tulips/5755467567_903c31e3d0.jpg
#   inflating: flower_photos/train/tulips/5757091018_cdfd79dfa6_m.jpg
#   inflating: flower_photos/train/tulips/5810456385_b44358a0ae.jpg
#   inflating: flower_photos/train/tulips/5811004432_266f0f0c6f.jpg
#   inflating: flower_photos/train/tulips/5811022098_2523ca4e82.jpg
#   inflating: flower_photos/train/tulips/5813495998_64be1b8ab6_n.jpg
#   inflating: flower_photos/train/tulips/5891485349_cce7b99549.jpg
#   inflating: flower_photos/train/tulips/6038098425_b3b4fb62cc_m.jpg
#   inflating: flower_photos/train/tulips/6187740107_9813ccc41e.jpg
#   inflating: flower_photos/train/tulips/6227136437_6117068599_m.jpg
#   inflating: flower_photos/train/tulips/6227136683_262c6be56b.jpg
#   inflating: flower_photos/train/tulips/6267021825_a8316e0dcc_m.jpg
#   inflating: flower_photos/train/tulips/6325571510_7544b27e57_n.jpg
#   inflating: flower_photos/train/tulips/65347450_53658c63bd_n.jpg
#   inflating: flower_photos/train/tulips/6539831765_c21b68910e_n.jpg
#   inflating: flower_photos/train/tulips/6770436217_281da51e49_n.jpg
#   inflating: flower_photos/train/tulips/6799076717_575944af91_m.jpg
#   inflating: flower_photos/train/tulips/6808860548_53796b90ca_n.jpg
#   inflating: flower_photos/train/tulips/6876631336_54bf150990.jpg
#   inflating: flower_photos/train/tulips/6903831250_a2757fff82_m.jpg
#   inflating: flower_photos/train/tulips/6905876618_12732b74de_b.jpg
#   inflating: flower_photos/train/tulips/6931489544_2f35025f7b_m.jpg
#   inflating: flower_photos/train/tulips/6931674908_8e93bd4554.jpg
#   inflating: flower_photos/train/tulips/6931708704_fccb06fea8.jpg
#   inflating: flower_photos/train/tulips/6931715360_34edc5a372_m.jpg
#   inflating: flower_photos/train/tulips/6931748252_68f06086b3.jpg
#   inflating: flower_photos/train/tulips/6934951920_d43ff8b78d.jpg
#   inflating: flower_photos/train/tulips/6936168062_a31c28b77c_m.jpg
#   inflating: flower_photos/train/tulips/6936380780_19c26c918a.jpg
#   inflating: flower_photos/train/tulips/6948239566_0ac0a124ee_n.jpg
#   inflating: flower_photos/train/tulips/6948277038_89d7ff42e2_m.jpg
#   inflating: flower_photos/train/tulips/6958243974_8851425ddb_n.jpg
#   inflating: flower_photos/train/tulips/6958342976_a4a9483488_n.jpg
#   inflating: flower_photos/train/tulips/6958343928_7e596da4ed_m.jpg
#   inflating: flower_photos/train/tulips/6970683464_f70838ca3a_n.jpg
#   inflating: flower_photos/train/tulips/6982913043_3b873c6a25.jpg
#   inflating: flower_photos/train/tulips/6989946990_62c639ff16_n.jpg
#   inflating: flower_photos/train/tulips/6994351792_343e18cbf6_n.jpg
#   inflating: flower_photos/train/tulips/6998661030_46cbb7892a.jpg
#   inflating: flower_photos/train/tulips/7002703410_3e97b29da5_n.jpg
#   inflating: flower_photos/train/tulips/7003964080_4566470798_n.jpg
#   inflating: flower_photos/train/tulips/7042692841_f323799c0d.jpg
#   inflating: flower_photos/train/tulips/7046815693_f159e96acd_n.jpg
#   inflating: flower_photos/train/tulips/7047408023_6e98fd1e3f.jpg
#   inflating: flower_photos/train/tulips/7055500907_dcf2bb50e0.jpg
#   inflating: flower_photos/train/tulips/7064778965_ddcc6ee9f2.jpg
#   inflating: flower_photos/train/tulips/7064813645_f7f48fb527.jpg
#   inflating: flower_photos/train/tulips/7068715863_a534ac7884_n.jpg
#   inflating: flower_photos/train/tulips/7069622551_348d41c327_n.jpg
#   inflating: flower_photos/train/tulips/7070694881_e9a331fa4e_n.jpg
#   inflating: flower_photos/train/tulips/7082476907_99beef0dde.jpg
#   inflating: flower_photos/train/tulips/7082608511_f4cf233f59_n.jpg
#   inflating: flower_photos/train/tulips/7094271655_79a6f972c1_n.jpg
#   inflating: flower_photos/train/tulips/7094415739_6b29e5215c_m.jpg
#   inflating: flower_photos/train/tulips/7136973281_b2a935ce20.jpg
#   inflating: flower_photos/train/tulips/7144016605_e159b6c06b_m.jpg
#   inflating: flower_photos/train/tulips/7145978709_2d1596f462.jpg
#   inflating: flower_photos/train/tulips/7166539842_43b7e02883.jpg
#   inflating: flower_photos/train/tulips/7166550328_de0d73cfa9.jpg
#   inflating: flower_photos/train/tulips/7166552648_28b6dce578.jpg
#   inflating: flower_photos/train/tulips/7166554924_432aaae4b2_n.jpg
#   inflating: flower_photos/train/tulips/7166564830_8b34a3fd35_n.jpg
#   inflating: flower_photos/train/tulips/7166567320_0a2beb6d42.jpg
#   inflating: flower_photos/train/tulips/7166570828_7c26ca5766_n.jpg
#   inflating: flower_photos/train/tulips/7166598930_18d8686ace_n.jpg
#   inflating: flower_photos/train/tulips/7166606598_5d2cd307c3.jpg
#   inflating: flower_photos/train/tulips/7166618384_850905fc63_n.jpg
#   inflating: flower_photos/train/tulips/7166626128_8e0983ac8e_n.jpg
#   inflating: flower_photos/train/tulips/7166635566_ee240b5408_n.jpg
#   inflating: flower_photos/train/tulips/7166640338_46b15d9ec8_n.jpg
#   inflating: flower_photos/train/tulips/7166644048_b00a14f01b.jpg
#   inflating: flower_photos/train/tulips/7166646966_41d83cd703.jpg
#   inflating: flower_photos/train/tulips/7177682195_c29265748d_n.jpg
#   inflating: flower_photos/train/tulips/7179796338_05e8b1c87b.jpg
#   inflating: flower_photos/train/tulips/7205145492_baec4dbb94.jpg
#   inflating: flower_photos/train/tulips/7205698252_b972087cc2.jpg
#   inflating: flower_photos/train/tulips/7247182064_f8d6759446_n.jpg
#   inflating: flower_photos/train/tulips/7266196114_c2a736a15a_m.jpg
#   inflating: flower_photos/train/tulips/7342871880_c17fe0eb4f_m.jpg
#   inflating: flower_photos/train/tulips/738207467_fc59cfcd9b_z.jpg
#   inflating: flower_photos/train/tulips/7447655334_e8f805ab95_m.jpg
#   inflating: flower_photos/train/tulips/7448453762_aea8739f1b.jpg
#   inflating: flower_photos/train/tulips/7481204112_e3c57dd40a_n.jpg
#   inflating: flower_photos/train/tulips/7481215720_73e40f178f_n.jpg
#   inflating: flower_photos/train/tulips/7481217920_6f65766a1c_n.jpg
#   inflating: flower_photos/train/tulips/7775145448_c42e638a6a_n.jpg
#   inflating: flower_photos/train/tulips/779359602_30abcbf5bb_n.jpg
#   inflating: flower_photos/train/tulips/7806320016_fcddfc1f8f_n.jpg
#   inflating: flower_photos/train/tulips/8394186551_28eed83a94_m.jpg
#   inflating: flower_photos/train/tulips/8454707381_453b4862eb_m.jpg
#   inflating: flower_photos/train/tulips/8454719295_4276c0e9c5_n.jpg
#   inflating: flower_photos/train/tulips/8484905084_6a18c62b13_m.jpg
#   inflating: flower_photos/train/tulips/8511683706_4173683d45_m.jpg
#   inflating: flower_photos/train/tulips/8520482921_21dd204ebd_n.jpg
#   inflating: flower_photos/train/tulips/8520488975_a50d377f91.jpg
#   inflating: flower_photos/train/tulips/8521597402_4b6169ba05.jpg
#   inflating: flower_photos/train/tulips/8523133474_d2c0845b54.jpg
#   inflating: flower_photos/train/tulips/8554190977_37ac747799_m.jpg
#   inflating: flower_photos/train/tulips/8555123165_2fe57eff4f.jpg
#   inflating: flower_photos/train/tulips/8562853756_73778dac25_n.jpg
#   inflating: flower_photos/train/tulips/8572847041_d0cc07861f_n.jpg
#   inflating: flower_photos/train/tulips/8601596054_33e40c2a7a.jpg
#   inflating: flower_photos/train/tulips/8603340662_0779bd87fd.jpg
#   inflating: flower_photos/train/tulips/8605564823_7a59d3d92a.jpg
#   inflating: flower_photos/train/tulips/8614237582_74417799f4_m.jpg
#   inflating: flower_photos/train/tulips/8619064872_dea79a9eb9.jpg
#   inflating: flower_photos/train/tulips/8622237974_b362574785_n.jpg
#   inflating: flower_photos/train/tulips/8623170936_83f4152431.jpg
#   inflating: flower_photos/train/tulips/8623173256_3f0eb4c506.jpg
#   inflating: flower_photos/train/tulips/8628453641_6f87755815_m.jpg
#   inflating: flower_photos/train/tulips/8659691170_09db83d023.jpg
#   inflating: flower_photos/train/tulips/8668973377_c69527db42_m.jpg
#   inflating: flower_photos/train/tulips/8668974855_8389ecbdca_m.jpg
#   inflating: flower_photos/train/tulips/8669794378_97dda6036f_n.jpg
#   inflating: flower_photos/train/tulips/8673412732_f8fd690ee4_n.jpg
#   inflating: flower_photos/train/tulips/8673416166_620fc18e2f_n.jpg
#   inflating: flower_photos/train/tulips/8673416556_639f5c88f1_n.jpg
#   inflating: flower_photos/train/tulips/8677713853_1312f65e71.jpg
#   inflating: flower_photos/train/tulips/8681825637_837a63513a_n.jpg
#   inflating: flower_photos/train/tulips/8686013485_3c4dfbfd1f_n.jpg
#   inflating: flower_photos/train/tulips/8686332852_c6dcb2e86b.jpg
#   inflating: flower_photos/train/tulips/8687675254_c93f50d8b0_m.jpg
#   inflating: flower_photos/train/tulips/8688502760_1c8d6de921_m.jpg
#   inflating: flower_photos/train/tulips/8689672277_b289909f97_n.jpg
#   inflating: flower_photos/train/tulips/8690789564_394eb04982_n.jpg
#   inflating: flower_photos/train/tulips/8690791226_b1f015259f_n.jpg
#   inflating: flower_photos/train/tulips/8695367666_0809529eaf_n.jpg
#   inflating: flower_photos/train/tulips/8695372372_302135aeb2.jpg
#   inflating: flower_photos/train/tulips/8697784345_e75913d220.jpg
#   inflating: flower_photos/train/tulips/8702982836_75222725d7.jpg
#   inflating: flower_photos/train/tulips/8706523526_a0f161b72b.jpg
#   inflating: flower_photos/train/tulips/8708209606_d3aede4801.jpg
#   inflating: flower_photos/train/tulips/8708856019_f3be2353a4_n.jpg
#   inflating: flower_photos/train/tulips/8710148289_6fc196a0f8_n.jpg
#   inflating: flower_photos/train/tulips/8711277462_b43df5454b_m.jpg
#   inflating: flower_photos/train/tulips/8712230357_1298b8513b.jpg
#   inflating: flower_photos/train/tulips/8712243901_54d686319e_m.jpg
#   inflating: flower_photos/train/tulips/8712244311_da8e90bf8e_n.jpg
#   inflating: flower_photos/train/tulips/8712260079_c0ff42e0e2_n.jpg
#   inflating: flower_photos/train/tulips/8712263493_3db76c5f82.jpg
#   inflating: flower_photos/train/tulips/8712266605_3787e346cd_n.jpg
#   inflating: flower_photos/train/tulips/8712267391_c756f18ee7_n.jpg
#   inflating: flower_photos/train/tulips/8712267813_f7a9be2ec5.jpg
#   inflating: flower_photos/train/tulips/8712268519_f4c2c39a06_n.jpg
#   inflating: flower_photos/train/tulips/8712269349_2b933da2b8_n.jpg
#   inflating: flower_photos/train/tulips/8712270243_8512cf4fbd.jpg
#   inflating: flower_photos/train/tulips/8712270665_57b5bda0a2_n.jpg
#   inflating: flower_photos/train/tulips/8712282563_3819afb7bc.jpg
#   inflating: flower_photos/train/tulips/8713357842_9964a93473_n.jpg
#   inflating: flower_photos/train/tulips/8713387500_6a9138b41b_n.jpg
#   inflating: flower_photos/train/tulips/8713388322_e5ae26263b_n.jpg
#   inflating: flower_photos/train/tulips/8713389178_66bceb71a8_n.jpg
#   inflating: flower_photos/train/tulips/8713390684_041148dd3e_n.jpg
#   inflating: flower_photos/train/tulips/8713391394_4b679ea1e3_n.jpg
#   inflating: flower_photos/train/tulips/8713392604_90631fb809_n.jpg
#   inflating: flower_photos/train/tulips/8713394070_b24561b0a9.jpg
#   inflating: flower_photos/train/tulips/8713396140_5af8136136.jpg
#   inflating: flower_photos/train/tulips/8713397358_0505cc0176_n.jpg
#   inflating: flower_photos/train/tulips/8713397694_bcbcbba2c2_n.jpg
#   inflating: flower_photos/train/tulips/8713398114_bc96f1b624_n.jpg
#   inflating: flower_photos/train/tulips/8713398614_88202e452e_n.jpg
#   inflating: flower_photos/train/tulips/8713398906_28e59a225a_n.jpg
#   inflating: flower_photos/train/tulips/8713407768_f880df361f.jpg
#   inflating: flower_photos/train/tulips/8717900362_2aa508e9e5.jpg
#   inflating: flower_photos/train/tulips/8722514702_7ecc68691c.jpg
#   inflating: flower_photos/train/tulips/8723767533_9145dec4bd_n.jpg
#   inflating: flower_photos/train/tulips/8729501081_b993185542_m.jpg
#   inflating: flower_photos/train/tulips/8733586143_3139db6e9e_n.jpg
#   inflating: flower_photos/train/tulips/8748266132_5298a91dcf_n.jpg
#   inflating: flower_photos/train/tulips/8750288831_5e49a9f29b.jpg
#   inflating: flower_photos/train/tulips/8757486380_90952c5377.jpg
#   inflating: flower_photos/train/tulips/8762189906_8223cef62f.jpg
#   inflating: flower_photos/train/tulips/8762193202_0fbf2f6a81.jpg
#   inflating: flower_photos/train/tulips/8768645961_8f1e097170_n.jpg
#   inflating: flower_photos/train/tulips/8817622133_a42bb90e38_n.jpg
#   inflating: flower_photos/train/tulips/8838347159_746d14e6c1_m.jpg
#   inflating: flower_photos/train/tulips/8838354855_c474fc66a3_m.jpg
#   inflating: flower_photos/train/tulips/8838914676_8ef4db7f50_n.jpg
#   inflating: flower_photos/train/tulips/8838975946_f54194894e_m.jpg
#   inflating: flower_photos/train/tulips/8838983024_5c1a767878_n.jpg
#   inflating: flower_photos/train/tulips/8892851067_79242a7362_n.jpg
#   inflating: flower_photos/train/tulips/8904780994_8867d64155_n.jpg
#   inflating: flower_photos/train/tulips/8908062479_449200a1b4.jpg
#   inflating: flower_photos/train/tulips/8908097235_c3e746d36e_n.jpg
#   inflating: flower_photos/train/tulips/9019694597_2d3bbedb17.jpg
#   inflating: flower_photos/train/tulips/9030467406_05e93ff171_n.jpg
#   inflating: flower_photos/train/tulips/9048307967_40a164a459_m.jpg
#   inflating: flower_photos/train/tulips/924782410_94ed7913ca_m.jpg
#   inflating: flower_photos/train/tulips/9378657435_89fabf13c9_n.jpg
#   inflating: flower_photos/train/tulips/9444202147_405290415b_n.jpg
#   inflating: flower_photos/train/tulips/9446982168_06c4d71da3_n.jpg
#   inflating: flower_photos/train/tulips/9831362123_5aac525a99_n.jpg
#   inflating: flower_photos/train/tulips/9870557734_88eb3b9e3b_n.jpg
#   inflating: flower_photos/train/tulips/9947374414_fdf1d0861c_n.jpg
#   inflating: flower_photos/train/tulips/9947385346_3a8cacea02_n.jpg
#   inflating: flower_photos/train/tulips/9976515506_d496c5e72c.jpg

# %% [markdown]
# ### Transforming the Data
#
# When we perform transfer learning, we have to shape our input data into the shape that the pre-trained model expects. VGG16 expects `224`-dim square images as input and so, we resize each flower image to fit this mold.

# %%
# load and transform data using ImageFolder

# VGG-16 Takes 224x224 images as input, so we resize all of them
data_transform = transforms.Compose([transforms.RandomResizedCrop(224), 
                                      transforms.ToTensor()])

train_data = datasets.ImageFolder(train_dir, transform=data_transform)
test_data = datasets.ImageFolder(test_dir, transform=data_transform)

# print out some data stats
print('Num training images: ', len(train_data))
print('Num test images: ', len(test_data))
# Out:
# Num training images:  3130
# Num test images:  540

# %% [markdown]
# ### DataLoaders and Data Visualization

# %%
# define dataloader parameters
batch_size = 20
num_workers=0

# prepare data loaders
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, 
                                           num_workers=num_workers, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, 
                                          num_workers=num_workers, shuffle=True)

# %%
# Visualize some sample data

# obtain one batch of training images
dataiter = iter(train_loader)
images, labels = dataiter.next()
images = images.numpy() # convert images to numpy for display

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(25, 4))
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    plt.imshow(np.transpose(images[idx], (1, 2, 0)))
    ax.set_title(classes[labels[idx]])

# %% [markdown]
# ---
# ## Define the Model
#
# To define a model for training we'll follow these steps:
# 1. Load in a pre-trained VGG16 model
# 2. "Freeze" all the parameters, so the net acts as a fixed feature extractor
# 3. Remove the last layer
# 4. Replace the last layer with a linear classifier of our own
#
# **Freezing simply means that the parameters in the pre-trained model will *not* change during training.**

# %%
# Load the pretrained model from pytorch
vgg16 = models.vgg16(pretrained=True)

# print out the model structure
print(vgg16)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
print(vgg16.classifier[6].in_features) 
print(vgg16.classifier[6].out_features)
# Out:
# 4096
# 1000

# %%
# Freeze training for all "features" layers
for param in vgg16.features.parameters():
    param.requires_grad = False

# %% [markdown]
# ---
# ### Final Classifier Layer
#
# Once you have the pre-trained feature extractor, you just need to modify and/or add to the final, fully-connected classifier layers. In this case, we suggest that you repace the last layer in the vgg classifier group of layers.
# > This layer should see as input the number of features produced by the portion of the network that you are not changing, and produce an appropriate number of outputs for the flower classification task.
#
# You can access any layer in a pretrained network by name and (sometimes) number, i.e. `vgg16.classifier[6]` is the sixth layer in a group of layers named "classifier".
#
# #### TODO: Replace the last fully-connected layer with one that produces the appropriate number of class scores.

# %%
import torch.nn as nn

## TODO: add a last linear layer  that maps n_inputs -> 5 flower classes
## new layers automatically have requires_grad = True

# Changing the output features of last Linear Layer 
vgg16.classifier[6].out_features = 5
print(vgg16.classifier[6])

# Checking the values of requires_grad of parameters
for param in vgg16.classifier[6].parameters():
  print(f"Requires_grad of parameter is {param.requires_grad}")

# after completing your model, if GPU is available, move the model to GPU
if train_on_gpu:
    vgg16.cuda()
# Out:
# Linear(in_features=4096, out_features=5, bias=True)
# Requires_grad of parameter is True
# Requires_grad of parameter is True

# %% [markdown]
# ### Specify [Loss Function](http://pytorch.org/docs/stable/nn.html#loss-functions) and [Optimizer](http://pytorch.org/docs/stable/optim.html)
#
# Below we'll use cross-entropy loss and stochastic gradient descent with a small learning rate. Note that the optimizer accepts as input _only_ the trainable parameters `vgg.classifier.parameters()`.

# %%
import torch.optim as optim

# specify loss function (categorical cross-entropy)
criterion = nn.CrossEntropyLoss()

# specify optimizer (stochastic gradient descent) and learning rate = 0.001
optimizer = optim.SGD(vgg16.classifier.parameters(), lr=0.001)

# %% [markdown]
# ---
# ## Training
#
# Here, we'll train the network.
#
# > **Exercise:** So far we've been providing the training code for you. Here, I'm going to give you a bit more of a challenge and have you write the code to train the network. Of course, you'll be able to see my solution if you need help.

# %%
# number of epochs to train the model
n_epochs = 2

## TODO complete epoch and training batch loops
## These loops should update the classifier-weights of this model
## And track (and print out) the training loss over time

# Epoch and Training Batch Loops
for e in range(1,n_epochs+1):
  train_loss = 0
  for batch_idx, (images, labels) in enumerate(train_loader):
    # move tensors to GPU if CUDA is available
    if train_on_gpu:
      images, labels = images.cuda(), labels.cuda()
    # clear the gradients 
    optimizer.zero_grad()
    # forward pass: calculate predicted probabilities by passing the images into the model
    output = vgg16(images)
    # calculate the loss 
    loss = criterion(output, labels)
    # backward Pass
    loss.backward()
    # update Weights
    optimizer.step()
    # update training loss
    train_loss += loss.item()
    # printing the epoch, batch and training loss
    if batch_idx % 20 == 19:
      print(f"Epoch: {e} Batch: {batch_idx+1} Training Loss: {train_loss/batch_size}")
      train_loss = 0
# Out:
# Epoch: 1 Batch: 20 Training Loss: 0.640228071808815
# Epoch: 1 Batch: 40 Training Loss: 0.670336565375328
# Epoch: 1 Batch: 60 Training Loss: 0.6041238367557525
# Epoch: 1 Batch: 80 Training Loss: 0.6098446279764176
# Epoch: 1 Batch: 100 Training Loss: 0.6269068047404289
# Epoch: 1 Batch: 120 Training Loss: 0.5908174738287926
# Epoch: 1 Batch: 140 Training Loss: 0.5875941306352616
# Epoch: 2 Batch: 20 Training Loss: 0.5584823004901409
# Epoch: 2 Batch: 40 Training Loss: 0.6010190844535828
# Epoch: 2 Batch: 60 Training Loss: 0.5829877704381943
# Epoch: 2 Batch: 80 Training Loss: 0.6255794584751129
# Epoch: 2 Batch: 100 Training Loss: 0.5369619935750961
# Epoch: 2 Batch: 120 Training Loss: 0.5504427276551723
# Epoch: 2 Batch: 140 Training Loss: 0.6430771306157113

# %% [markdown]
# ---
# ## Testing
#
# Below you see the test accuracy for each flower class.

# %%
# track test loss 
# over 5 flower classes
test_loss = 0.0
class_correct = list(0. for i in range(5))
class_total = list(0. for i in range(5))

vgg16.eval() # eval mode

# iterate over test data
for data, target in test_loader:
    # move tensors to GPU if CUDA is available
    if train_on_gpu:
        data, target = data.cuda(), target.cuda()
    # forward pass: compute predicted outputs by passing inputs to the model
    output = vgg16(data)
    # calculate the batch loss
    loss = criterion(output, target)
    # update  test loss 
    test_loss += loss.item()*data.size(0)
    # convert output probabilities to predicted class
    _, pred = torch.max(output, 1)    
    # compare predictions to true label
    correct_tensor = pred.eq(target.data.view_as(pred))
    correct = np.squeeze(correct_tensor.numpy()) if not train_on_gpu else np.squeeze(correct_tensor.cpu().numpy())
    # calculate test accuracy for each object class
    for i in range(batch_size):
        label = target.data[i]
        class_correct[label] += correct[i].item()
        class_total[label] += 1

# calculate avg test loss
test_loss = test_loss/len(test_loader.dataset)
print('Test Loss: {:.6f}\n'.format(test_loss))

for i in range(5):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
            classes[i], 100 * class_correct[i] / class_total[i],
            np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
# Out:
# Test Loss: 0.624949
#
# Test Accuracy of daisy: 76% (70/92)
# Test Accuracy of dandelion: 88% (117/132)
# Test Accuracy of roses: 67% (61/91)
# Test Accuracy of sunflowers: 80% (81/101)
# Test Accuracy of tulips: 67% (84/124)
#
# Test Accuracy (Overall): 76% (413/540)

# %% [markdown]
# ### Visualize Sample Test Results

# %%
# obtain one batch of test images
dataiter = iter(test_loader)
images, labels = dataiter.next()
images.numpy()

# move model inputs to cuda, if GPU available
if train_on_gpu:
    images = images.cuda()

# get sample outputs
output = vgg16(images)
# convert output probabilities to predicted class
_, preds_tensor = torch.max(output, 1)
preds = np.squeeze(preds_tensor.numpy()) if not train_on_gpu else np.squeeze(preds_tensor.cpu().numpy())

# plot the images in the batch, along with predicted and true labels
fig = plt.figure(figsize=(25, 4))
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    plt.imshow(np.transpose(images[idx].cpu(), (1, 2, 0)))
    ax.set_title("{} ({})".format(classes[preds[idx]], classes[labels[idx]]),
                 color=("green" if preds[idx]==labels[idx].item() else "red"))
